# %%
import pandas as pd
import numpy as np
from compression.utils.load import load_student_logs, load_teacher_logs
from compression.utils.plot import plot_logs

# %%
seeds = [1] #"/home/andrea/policy_compression/results"
# Note: results generated using beta=100 and 32x32 network. 
teacher_logs = load_teacher_logs(seeds = seeds, log_prefix = "evals/log_dagger", n_iterations = 25, agent_name="expert (Tube MPC)")
dagger_logs = load_student_logs(seeds = seeds, log_prefix = "log_dagger", n_iterations = 25, agent_name="baseline (DAgger)")
dagger_dr_logs = load_student_logs(seeds = seeds, log_prefix = "log_dagger_with_dr", n_iterations = 25, agent_name="baseline (DAgger + DR)")
dagger_augm_logs  = load_student_logs(seeds = seeds, log_prefix = "log_dagger_augm_vertexes", n_iterations = 25, agent_name="proposed (DAgger + Augm))")
logs = pd.concat([teacher_logs, dagger_logs, dagger_dr_logs, dagger_augm_logs], axis = 0, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-fcd73158ca46> in <module>
#       1 seeds = [1] #"/home/andrea/policy_compression/results"
#       2 # Note: results generated using beta=100 and 32x32 network.
# ----> 3 teacher_logs = load_teacher_logs(seeds = seeds, log_prefix = "evals/log_dagger", n_iterations = 25, agent_name="expert (Tube MPC)")
#       4 dagger_logs = load_student_logs(seeds = seeds, log_prefix = "log_dagger", n_iterations = 25, agent_name="baseline (DAgger)")
#       5 dagger_dr_logs = load_student_logs(seeds = seeds, log_prefix = "log_dagger_with_dr", n_iterations = 25, agent_name="baseline (DAgger + DR)")
#
# ~/Desktop/ws/src/panther/panther_compression/compression/utils/load.py in load_teacher_logs(seeds, log_prefix, n_iterations, agent_name)
#      37     for seed in seeds:
#      38         teacher.append(pd.read_pickle(os.path.join(log_prefix, str(seed), "teacher_no_dist.pkl")).assign(training = False))
# ---> 39         # teacher.append(pd.read_pickle(os.path.join(log_prefix, str(seed), "teacher_with_dist.pkl")).assign(training = False))
#      40     teacher_logs = pd.concat(teacher, axis=0, ignore_index=True)
#      41     # Repeat these numbers for every iteration (is there a better way?)
#
# ~/installations/venvs_python/my37/lib/python3.7/site-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression, storage_options)
#     199         compression=compression,
#     200         is_text=False,
# --> 201         storage_options=storage_options,
#     202     ) as handles:
#     203
#
# ~/installations/venvs_python/my37/lib/python3.7/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     709         else:
#     710             # Binary mode
# --> 711             handle = open(handle, ioargs.mode)
#     712         handles.append(handle)
#     713
#
# FileNotFoundError: [Errno 2] No such file or directory: 'evals/log_dagger/1/teacher_with_dist.pkl'

# %%
plot_logs(logs)
